# %% [markdown]
# # 1. Importation des Librairies

# %%
# importer les Packages
import numpy as np
import pandas as pd

# %% [markdown]
# # Charger les donnees

# %%
# # Charger les donnees
data = pd.read_csv('Data/DDoS_dataset.csv')
data.head()
# Out:
#       dt  switch       src       dst  pktcount  bytecount  dur   dur_nsec  \
# 0  11425       1  10.0.0.1  10.0.0.8     45304   48294064  100  716000000
# 1  11605       1  10.0.0.1  10.0.0.8    126395  134737070  280  734000000
# 2  11425       1  10.0.0.2  10.0.0.8     90333   96294978  200  744000000
# 3  11425       1  10.0.0.2  10.0.0.8     90333   96294978  200  744000000
# 4  11425       1  10.0.0.2  10.0.0.8     90333   96294978  200  744000000
#
#         tot_dur  flows  ...  pktrate  Pairflow  Protocol  port_no   tx_bytes  \
# 0  1.010000e+11      3  ...      451         0       UDP        3  143928631
# 1  2.810000e+11      2  ...      451         0       UDP        4       3842
# 2  2.010000e+11      3  ...      451         0       UDP        1       3795
# 3  2.010000e+11      3  ...      451         0       UDP        2       3688
# 4  2.010000e+11      3  ...      451         0       UDP        3       3413
#
#   rx_bytes  tx_kbps  rx_kbps  tot_kbps  label
# 0     3917        0      0.0       0.0      0
# 1     3520        0      0.0       0.0      0
# 2     1242        0      0.0       0.0      0
# 3     1492        0      0.0       0.0      0
# 4     3665        0      0.0       0.0      0
#
# [5 rows x 23 columns]

# %% [markdown]
# # Étape 3 : Analyse de données

# %%
# Étape 3 : Analyse de données
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 104345 entries, 0 to 104344
# Data columns (total 23 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   dt           104345 non-null  int64
#  1   switch       104345 non-null  int64
#  2   src          104345 non-null  object
#  3   dst          104345 non-null  object
#  4   pktcount     104345 non-null  int64
#  5   bytecount    104345 non-null  int64
#  6   dur          104345 non-null  int64
#  7   dur_nsec     104345 non-null  int64
#  8   tot_dur      104345 non-null  float64
#  9   flows        104345 non-null  int64
#  10  packetins    104345 non-null  int64
#  11  pktperflow   104345 non-null  int64
#  12  byteperflow  104345 non-null  int64
#  13  pktrate      104345 non-null  int64
#  14  Pairflow     104345 non-null  int64
#  15  Protocol     104345 non-null  object
#  16  port_no      104345 non-null  int64
#  17  tx_bytes     104345 non-null  int64
#  18  rx_bytes     104345 non-null  int64
#  19  tx_kbps      104345 non-null  int64
#  20  rx_kbps      103839 non-null  float64
#  21  tot_kbps     103839 non-null  float64
#  22  label        104345 non-null  int64
# dtypes: float64(3), int64(17), object(3)
# memory usage: 18.3+ MB

# %%
data['src'].unique()
# Out:
# array(['10.0.0.1', '10.0.0.2', '10.0.0.4', '10.0.0.10', '10.0.0.3',
#        '10.0.0.5', '10.0.0.13', '10.0.0.6', '10.0.0.20', '10.0.0.11',
#        '10.0.0.12', '10.0.0.18', '10.0.0.8', '10.0.0.7', '10.0.0.9',
#        '10.0.0.14', '10.0.0.15', '10.0.0.16', '10.0.0.17'], dtype=object)

# %%
data['dst'].unique()
# Out:
# array(['10.0.0.8', '10.0.0.7', '10.0.0.3', '10.0.0.5', '10.0.0.10',
#        '10.0.0.13', '10.0.0.1', '10.0.0.11', '10.0.0.2', '10.0.0.4',
#        '10.0.0.9', '10.0.0.6', '10.0.0.14', '10.0.0.15', '10.0.0.12',
#        '10.0.0.16', '10.0.0.17', '10.0.0.18'], dtype=object)

# %%
data['Protocol'].unique()
# Out:
# array(['UDP', 'TCP', 'ICMP'], dtype=object)

# %%
data.drop(columns='src', inplace=True, axis=1)
data.drop(columns='dst', inplace=True, axis=1)
data.head()
# Out:
#       dt  switch  pktcount  bytecount  dur   dur_nsec       tot_dur  flows  \
# 0  11425       1     45304   48294064  100  716000000  1.010000e+11      3
# 1  11605       1    126395  134737070  280  734000000  2.810000e+11      2
# 2  11425       1     90333   96294978  200  744000000  2.010000e+11      3
# 3  11425       1     90333   96294978  200  744000000  2.010000e+11      3
# 4  11425       1     90333   96294978  200  744000000  2.010000e+11      3
#
#    packetins  pktperflow  ...  pktrate  Pairflow  Protocol port_no   tx_bytes  \
# 0       1943       13535  ...      451         0       UDP       3  143928631
# 1       1943       13531  ...      451         0       UDP       4       3842
# 2       1943       13534  ...      451         0       UDP       1       3795
# 3       1943       13534  ...      451         0       UDP       2       3688
# 4       1943       13534  ...      451         0       UDP       3       3413
#
#    rx_bytes  tx_kbps  rx_kbps  tot_kbps  label
# 0      3917        0      0.0       0.0      0
# 1      3520        0      0.0       0.0      0
# 2      1242        0      0.0       0.0      0
# 3      1492        0      0.0       0.0      0
# 4      3665        0      0.0       0.0      0
#
# [5 rows x 21 columns]

# %% [markdown]
# # Étape 4 : Prétraitement des données

# %%
from sklearn.preprocessing import LabelEncoder

# %%
encoder = LabelEncoder()

# %%
data['Protocol'] = encoder.fit_transform(data['Protocol'])
data.head()
# Out:
#       dt  switch  pktcount  bytecount  dur   dur_nsec       tot_dur  flows  \
# 0  11425       1     45304   48294064  100  716000000  1.010000e+11      3
# 1  11605       1    126395  134737070  280  734000000  2.810000e+11      2
# 2  11425       1     90333   96294978  200  744000000  2.010000e+11      3
# 3  11425       1     90333   96294978  200  744000000  2.010000e+11      3
# 4  11425       1     90333   96294978  200  744000000  2.010000e+11      3
#
#    packetins  pktperflow  ...  pktrate  Pairflow  Protocol  port_no  \
# 0       1943       13535  ...      451         0         2        3
# 1       1943       13531  ...      451         0         2        4
# 2       1943       13534  ...      451         0         2        1
# 3       1943       13534  ...      451         0         2        2
# 4       1943       13534  ...      451         0         2        3
#
#     tx_bytes  rx_bytes  tx_kbps  rx_kbps  tot_kbps  label
# 0  143928631      3917        0      0.0       0.0      0
# 1       3842      3520        0      0.0       0.0      0
# 2       3795      1242        0      0.0       0.0      0
# 3       3688      1492        0      0.0       0.0      0
# 4       3413      3665        0      0.0       0.0      0
#
# [5 rows x 21 columns]

# %%
data['Protocol'].unique()
# Out:
# array([2, 1, 0])

# %%
data.isnull().sum()
# Out:
# dt               0
# switch           0
# pktcount         0
# bytecount        0
# dur              0
# dur_nsec         0
# tot_dur          0
# flows            0
# packetins        0
# pktperflow       0
# byteperflow      0
# pktrate          0
# Pairflow         0
# Protocol         0
# port_no          0
# tx_bytes         0
# rx_bytes         0
# tx_kbps          0
# rx_kbps        506
# tot_kbps       506
# label            0
# dtype: int64

# %%
import seaborn as sns

# %%
sns.heatmap(data.isnull())
# Out:
# <Axes: >

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# Gestion des valeurs manquantes
data['rx_kbps'].fillna(data['rx_kbps'].mean(), inplace=True)
data['tot_kbps'].fillna(data['tot_kbps'].mean(), inplace=True)
data.isnull().sum()
# Out:
# dt             0
# switch         0
# pktcount       0
# bytecount      0
# dur            0
# dur_nsec       0
# tot_dur        0
# flows          0
# packetins      0
# pktperflow     0
# byteperflow    0
# pktrate        0
# Pairflow       0
# Protocol       0
# port_no        0
# tx_bytes       0
# rx_bytes       0
# tx_kbps        0
# rx_kbps        0
# tot_kbps       0
# label          0
# dtype: int64

# %%
data
# Out:
#            dt  switch  pktcount  bytecount  dur   dur_nsec       tot_dur  \
# 0       11425       1     45304   48294064  100  716000000  1.010000e+11
# 1       11605       1    126395  134737070  280  734000000  2.810000e+11
# 2       11425       1     90333   96294978  200  744000000  2.010000e+11
# 3       11425       1     90333   96294978  200  744000000  2.010000e+11
# 4       11425       1     90333   96294978  200  744000000  2.010000e+11
# ...       ...     ...       ...        ...  ...        ...           ...
# 104340   5262       3        79       7742   81  842000000  8.184200e+10
# 104341   5262       3        79       7742   81  842000000  8.184200e+10
# 104342   5262       3        31       3038   31  805000000  3.180500e+10
# 104343   5262       3        31       3038   31  805000000  3.180500e+10
# 104344   5262       3        31       3038   31  805000000  3.180500e+10
#
#         flows  packetins  pktperflow  ...  pktrate  Pairflow  Protocol  \
# 0           3       1943       13535  ...      451         0         2
# 1           2       1943       13531  ...      451         0         2
# 2           3       1943       13534  ...      451         0         2
# 3           3       1943       13534  ...      451         0         2
# 4           3       1943       13534  ...      451         0         2
# ...       ...        ...         ...  ...      ...       ...       ...
# 104340      5         10          29  ...        0         0         0
# 104341      5         10          29  ...        0         0         0
# 104342      5         10          30  ...        1         0         0
# 104343      5         10          30  ...        1         0         0
# 104344      5         10          30  ...        1         0         0
#
#         port_no   tx_bytes  rx_bytes  tx_kbps  rx_kbps  tot_kbps  label
# 0             3  143928631      3917        0      0.0       0.0      0
# 1             4       3842      3520        0      0.0       0.0      0
# 2             1       3795      1242        0      0.0       0.0      0
# 3             2       3688      1492        0      0.0       0.0      0
# 4             3       3413      3665        0      0.0       0.0      0
# ...         ...        ...       ...      ...      ...       ...    ...
# 104340        1      15209     12720        1      1.0       2.0      0
# 104341        3      15099     14693        1      1.0       2.0      0
# 104342        2       3409      3731        0      0.0       0.0      0
# 104343        1      15209     12720        1      1.0       2.0      0
# 104344        3      15099     14693        1      1.0       2.0      0
#
# [104345 rows x 21 columns]

# %% [markdown]
# # Étape 5 : Diviser les données : Train et Test (Normaliser les données)

# %%
data.columns
# Out:
# Index(['dt', 'switch', 'pktcount', 'bytecount', 'dur', 'dur_nsec', 'tot_dur',
#        'flows', 'packetins', 'pktperflow', 'byteperflow', 'pktrate',
#        'Pairflow', 'Protocol', 'port_no', 'tx_bytes', 'rx_bytes', 'tx_kbps',
#        'rx_kbps', 'tot_kbps', 'label'],
#       dtype='object')

# %%
#Étape 5 : Diviser les données : Train et Test (Normaliser les données)
#X = data.drop(columns='label', inplace=True, axis=1)
#y = data['label']
X = data.iloc[ : , :-1]
y = data.iloc[ : , -1]

# %%
X
# Out:
#            dt  switch  pktcount  bytecount  dur   dur_nsec       tot_dur  \
# 0       11425       1     45304   48294064  100  716000000  1.010000e+11
# 1       11605       1    126395  134737070  280  734000000  2.810000e+11
# 2       11425       1     90333   96294978  200  744000000  2.010000e+11
# 3       11425       1     90333   96294978  200  744000000  2.010000e+11
# 4       11425       1     90333   96294978  200  744000000  2.010000e+11
# ...       ...     ...       ...        ...  ...        ...           ...
# 104340   5262       3        79       7742   81  842000000  8.184200e+10
# 104341   5262       3        79       7742   81  842000000  8.184200e+10
# 104342   5262       3        31       3038   31  805000000  3.180500e+10
# 104343   5262       3        31       3038   31  805000000  3.180500e+10
# 104344   5262       3        31       3038   31  805000000  3.180500e+10
#
#         flows  packetins  pktperflow  byteperflow  pktrate  Pairflow  \
# 0           3       1943       13535     14428310      451         0
# 1           2       1943       13531     14424046      451         0
# 2           3       1943       13534     14427244      451         0
# 3           3       1943       13534     14427244      451         0
# 4           3       1943       13534     14427244      451         0
# ...       ...        ...         ...          ...      ...       ...
# 104340      5         10          29         2842        0         0
# 104341      5         10          29         2842        0         0
# 104342      5         10          30         2940        1         0
# 104343      5         10          30         2940        1         0
# 104344      5         10          30         2940        1         0
#
#         Protocol  port_no   tx_bytes  rx_bytes  tx_kbps  rx_kbps  tot_kbps
# 0              2        3  143928631      3917        0      0.0       0.0
# 1              2        4       3842      3520        0      0.0       0.0
# 2              2        1       3795      1242        0      0.0       0.0
# 3              2        2       3688      1492        0      0.0       0.0
# 4              2        3       3413      3665        0      0.0       0.0
# ...          ...      ...        ...       ...      ...      ...       ...
# 104340         0        1      15209     12720        1      1.0       2.0
# 104341         0        3      15099     14693        1      1.0       2.0
# 104342         0        2       3409      3731        0      0.0       0.0
# 104343         0        1      15209     12720        1      1.0       2.0
# 104344         0        3      15099     14693        1      1.0       2.0
#
# [104345 rows x 20 columns]

# %%
y
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 104340    0
# 104341    0
# 104342    0
# 104343    0
# 104344    0
# Name: label, Length: 104345, dtype: int64

# %%
# Splitting 
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
standar_scaler = StandardScaler()
X = standar_scaler.fit_transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.23, random_state=40)

# %%
print("X-train:", X_train.shape)
print("X-test:", X_test.shape)
print("y-train:", y_train.shape)
print("y-train:", y_test.shape)
# Out:
# X-train: (80345, 20)
# X-test: (24000, 20)
# y-train: (80345,)
# y-train: (24000,)

# %% [markdown]
# # Étape 6 : Construire le Shallow Neural Network

# %%
# Étape 6 : Construire le Shallow Neural Network
# Pour installer Tensorflow : pip install tensorflow  / conda install tensorflow
# Pour installer keras : pip install keras / conda install keras

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam

# %%
# Creation du model
model = Sequential()

# %%
# Ajout de la couche d'entree == couche cachee
model.add(Dense(10, input_shape=(20,), activation='relu'))
#model.add(Dense(16, input_shape=(9,), activation='relu'))
#model.add(Dense(32, activation='relu'))

# Ajout de la couche de sortie
model.add(Dense(1, activation='sigmoid'))

# Compiler le modele
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Affichage de l'architecture ou la structure du model
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 10)             │           210 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            11 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 221 (884.00 B)
#  Trainable params: 221 (884.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
# Entrainement du modele
history = model.fit(X_train, y_train, epochs=75, verbose=1, validation_data=(X_test, y_test))
# Out:
# Epoch 1/75
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7818 - loss: 0.4319 - val_accuracy: 0.9395 - val_loss: 0.1629
# Epoch 2/75
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.9443 - loss: 0.1467 - val_accuracy: 0.9506 - val_loss: 0.1261
# Epoch 3/75
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.9543 - loss: 0.1172 - val_accuracy: 0.9554 - val_loss: 0.1115
# Epoch 4/75
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.9563 - loss: 0.1064 - val_accuracy: 0.9568 - val_loss: 0.1028
# Epoch 5/75
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.9588 - loss: 0.0986 - val_accuracy: 0.9589 - val_loss: 0.0952
# Epoch 6/75
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.9625 - loss: 0.0891 - val_accuracy: 0.9621 - val_loss: 0.0907
# Epoch 7/75
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.9634 - loss: 0.0884 - val_accuracy: 0.9643 - val_loss: 0.0879
# Epoch 8/75
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.9654 - loss: 0.0854 - val_accuracy: 0.9654 - val_loss: 0.0851
# Epoch 9/75
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.9671 - loss: 0.0823 - val_accuracy: 0.9654 - val_loss: 0.0818
# Epoch 10/75
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.9693 - loss: 0.0778 - val_accuracy: 0.9683 - val_loss: 0.0792
# Epoch 11/75
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.9694 - loss: 0.0759 - val_accuracy: 0.9694 - val_loss: 0.0763
# Epoch 12/75
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.9714 - loss: 0.0721 - val_accuracy: 0.9709 - val_loss: 0.0742
# Epoch 13/75
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.9728 - loss: 0.0704 - val_accuracy: 0.9723 - val_loss: 0.0710
# Epoch 14/75
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.9744 - loss: 0.0679 - val_accuracy: 0.9737 - val_loss: 0.0680
# Epoch 15/75
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9753 - loss: 0.0650 - val_accuracy: 0.9738 - val_loss: 0.0671
# Epoch 16/75
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9753 - loss: 0.0641 - val_accuracy: 0.9734 - val_loss: 0.0648
# Epoch 17/75
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.9771 - loss: 0.0612 - val_accuracy: 0.9763 - val_loss: 0.0616
# Epoch 18/75
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.9793 - loss: 0.0579 - val_accuracy: 0.9789 - val_loss: 0.0595
# Epoch 19/75
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.9799 - loss: 0.0559 - val_accuracy: 0.9768 - val_loss: 0.0581
# Epoch 20/75
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9795 - loss: 0.0554 - val_accuracy: 0.9782 - val_loss: 0.0563
# Epoch 21/75
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9816 - loss: 0.0514 - val_accuracy: 0.9771 - val_loss: 0.0558
# Epoch 22/75
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.9815 - loss: 0.0502 - val_accuracy: 0.9791 - val_loss: 0.0530
# Epoch 23/75
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.9820 - loss: 0.0490 - val_accuracy: 0.9805 - val_loss: 0.0508
# Epoch 24/75
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.9827 - loss: 0.0464 - val_accuracy: 0.9808 - val_loss: 0.0491
# Epoch 25/75
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9843 - loss: 0.0442 - val_accuracy: 0.9822 - val_loss: 0.0477
# Epoch 26/75
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.9839 - loss: 0.0440 - val_accuracy: 0.9815 - val_loss: 0.0469
# Epoch 27/75
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.9844 - loss: 0.0427 - val_accuracy: 0.9820 - val_loss: 0.0450
# Epoch 28/75
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.9849 - loss: 0.0409 - val_accuracy: 0.9832 - val_loss: 0.0437
# Epoch 29/75
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9852 - loss: 0.0405 - val_accuracy: 0.9834 - val_loss: 0.0429
# Epoch 30/75
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.9855 - loss: 0.0385 - val_accuracy: 0.9847 - val_loss: 0.0424
# Epoch 31/75
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.9848 - loss: 0.0398 - val_accuracy: 0.9833 - val_loss: 0.0416
# Epoch 32/75
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.9855 - loss: 0.0378 - val_accuracy: 0.9842 - val_loss: 0.0406
# Epoch 33/75
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9863 - loss: 0.0368 - val_accuracy: 0.9842 - val_loss: 0.0400
# Epoch 34/75
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9864 - loss: 0.0357 - val_accuracy: 0.9836 - val_loss: 0.0394
# Epoch 35/75
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.9865 - loss: 0.0350 - val_accuracy: 0.9855 - val_loss: 0.0378
# Epoch 36/75
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.9875 - loss: 0.0340 - val_accuracy: 0.9851 - val_loss: 0.0376
# Epoch 37/75
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.9874 - loss: 0.0338 - val_accuracy: 0.9845 - val_loss: 0.0375
# Epoch 38/75
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9863 - loss: 0.0344 - val_accuracy: 0.9855 - val_loss: 0.0363
# Epoch 39/75
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.9867 - loss: 0.0335 - val_accuracy: 0.9858 - val_loss: 0.0355
# Epoch 40/75
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.9870 - loss: 0.0328 - val_accuracy: 0.9853 - val_loss: 0.0344
# Epoch 41/75
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.9876 - loss: 0.0319 - val_accuracy: 0.9853 - val_loss: 0.0348
# Epoch 42/75
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9881 - loss: 0.0303 - val_accuracy: 0.9856 - val_loss: 0.0336
# Epoch 43/75
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.9874 - loss: 0.0316 - val_accuracy: 0.9864 - val_loss: 0.0331
# Epoch 44/75
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9872 - loss: 0.0314 - val_accuracy: 0.9873 - val_loss: 0.0327
# Epoch 45/75
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9880 - loss: 0.0297 - val_accuracy: 0.9866 - val_loss: 0.0324
# Epoch 46/75
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.9878 - loss: 0.0300 - val_accuracy: 0.9873 - val_loss: 0.0317
# Epoch 47/75
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.9881 - loss: 0.0300 - val_accuracy: 0.9875 - val_loss: 0.0316
# Epoch 48/75
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.9885 - loss: 0.0292 - val_accuracy: 0.9868 - val_loss: 0.0309
# Epoch 49/75
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9878 - loss: 0.0288 - val_accuracy: 0.9877 - val_loss: 0.0306
# Epoch 50/75
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.9893 - loss: 0.0281 - val_accuracy: 0.9871 - val_loss: 0.0309
# Epoch 51/75
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.9894 - loss: 0.0282 - val_accuracy: 0.9875 - val_loss: 0.0307
# Epoch 52/75
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9884 - loss: 0.0282 - val_accuracy: 0.9875 - val_loss: 0.0300
# Epoch 53/75
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9892 - loss: 0.0274 - val_accuracy: 0.9877 - val_loss: 0.0298
# Epoch 54/75
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.9880 - loss: 0.0282 - val_accuracy: 0.9870 - val_loss: 0.0310
# Epoch 55/75
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.9887 - loss: 0.0273 - val_accuracy: 0.9874 - val_loss: 0.0294
# Epoch 56/75
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9885 - loss: 0.0280 - val_accuracy: 0.9881 - val_loss: 0.0294
# Epoch 57/75
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9890 - loss: 0.0273 - val_accuracy: 0.9871 - val_loss: 0.0304
# Epoch 58/75
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9889 - loss: 0.0269 - val_accuracy: 0.9877 - val_loss: 0.0297
# Epoch 59/75
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.9886 - loss: 0.0274 - val_accuracy: 0.9870 - val_loss: 0.0300
# Epoch 60/75
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9889 - loss: 0.0273 - val_accuracy: 0.9883 - val_loss: 0.0285
# Epoch 61/75
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9891 - loss: 0.0263 - val_accuracy: 0.9877 - val_loss: 0.0291
# Epoch 62/75
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9890 - loss: 0.0267 - val_accuracy: 0.9893 - val_loss: 0.0281
# Epoch 63/75
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9893 - loss: 0.0260 - val_accuracy: 0.9887 - val_loss: 0.0285
# Epoch 64/75
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9891 - loss: 0.0266 - val_accuracy: 0.9879 - val_loss: 0.0286
# Epoch 65/75
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.9893 - loss: 0.0261 - val_accuracy: 0.9888 - val_loss: 0.0279
# Epoch 66/75
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9890 - loss: 0.0269 - val_accuracy: 0.9877 - val_loss: 0.0289
# Epoch 67/75
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9887 - loss: 0.0259 - val_accuracy: 0.9882 - val_loss: 0.0283
# Epoch 68/75
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9895 - loss: 0.0258 - val_accuracy: 0.9882 - val_loss: 0.0278
# Epoch 69/75
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9898 - loss: 0.0252 - val_accuracy: 0.9890 - val_loss: 0.0279
# Epoch 70/75
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9896 - loss: 0.0260 - val_accuracy: 0.9880 - val_loss: 0.0283
# Epoch 71/75
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9888 - loss: 0.0270 - val_accuracy: 0.9893 - val_loss: 0.0273
# Epoch 72/75
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9893 - loss: 0.0254 - val_accuracy: 0.9883 - val_loss: 0.0272
# Epoch 73/75
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.9895 - loss: 0.0248 - val_accuracy: 0.9886 - val_loss: 0.0279
# Epoch 74/75
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9896 - loss: 0.0251 - val_accuracy: 0.9879 - val_loss: 0.0283
# Epoch 75/75
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9892 - loss: 0.0257 - val_accuracy: 0.9877 - val_loss: 0.0277

# %% [markdown]
# # Étape 7 : Visualiser l’évolution de l’entrainement du réseau de neurone

# %%
history

# %%
# Étape 7 : Visualiser l’évolution de l’entrainement du réseau de neurone
import matplotlib.pyplot as plt

# %%
epoch_accuracy = history.history['accuracy']
epoch_loss = history.history['loss']

epoch_val_accuracy = history.history['val_accuracy']
epoch_val_loss = history.history['val_loss']

# %%
plt.figure(figsize=(15, 6))
plt.plot(range(0, len(epoch_accuracy)), epoch_accuracy, color='blue', label='Training Accuracy')
plt.plot(range(0, len(epoch_loss)), epoch_loss, color='red', label='Training Loss')
plt.xlabel('Epochs')
plt.ylabel('Valeur')
plt.title('Accuracy Vs Loss')
plt.legend()
plt.plot()
plt.show()

# %%
plt.figure(figsize=(15, 6))
plt.plot(range(0, len(epoch_accuracy)), epoch_accuracy, color='blue', label='Training Accuracy')
plt.plot(range(0, len(epoch_val_accuracy)), epoch_val_accuracy, color='red', label='Test Loss')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Training Accuracy Vs Test Accuracy')
plt.legend()
plt.plot()
plt.show()

# %%
plt.figure(figsize=(15, 6))
plt.plot(range(0, len(epoch_loss)), epoch_loss, color='blue', label='Training Loss')
plt.plot(range(0, len(epoch_val_loss)), epoch_val_loss, color='red', label='Test Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Loss Vs Test Loss')
plt.legend()
plt.plot()
plt.show()

# %% [markdown]
# # Étape 8 : Evaluer le modèle

# %%
# Étape 8 : Evaluer le modèle
model.evaluate(X_test, y_test)
# Out:
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9883 - loss: 0.0257
# [0.027691354975104332, 0.987708330154419]
